# %%
# %matplotlib inline

# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd

# File to Load
ride_data_to_load = "../RideData.csv"
city_data_to_load = "../CityData.csv"

#Read File as a Dataframe
ride_data = pd.read_csv(ride_data_to_load)
city_data = pd.read_csv(city_data_to_load)
print(ride_data.head())
print(city_data.head())

#Merge Files with a Left or Natural Merge
pyber_df = pd.merge(ride_data, city_data, on="city", how="left")

pyber_df.head()
# Out:
#                  city             date   fare       ride_id
# 0  Lake Jonathanshire  1/14/2018 10:14  13.83  5.739410e+12
# 1  South Michelleport   3/4/2018 18:24  30.24  2.343910e+12
# 2  Port Samanthamouth   2/24/2018 4:29  33.44  2.005070e+12
# 3          Rodneyfort  2/10/2018 23:22  23.44  5.149250e+12
# 4          South Jack    3/6/2018 4:28  34.58  3.908450e+12
#            city  driver_count   type
# 0   Richardfort            38  Urban
# 1  Williamsstad            59  Urban
# 2   Port Angela            67  Urban
# 3    Rodneyfort            34  Urban
# 4   West Robert            39  Urban
#                  city             date   fare       ride_id  driver_count  \
# 0  Lake Jonathanshire  1/14/2018 10:14  13.83  5.739410e+12             5
# 1  South Michelleport   3/4/2018 18:24  30.24  2.343910e+12            72
# 2  Port Samanthamouth   2/24/2018 4:29  33.44  2.005070e+12            57
# 3          Rodneyfort  2/10/2018 23:22  23.44  5.149250e+12            34
# 4          South Jack    3/6/2018 4:28  34.58  3.908450e+12            46
#
#     type
# 0  Urban
# 1  Urban
# 2  Urban
# 3  Urban
# 4  Urban

# %%
#Establish Coordinates for Types of Cities
urban_area = pyber_df[pyber_df["type"] == "Urban"].groupby([pyber_df["city"]])
urban_x_coordinate = urban_area["ride_id"].count()
urban_y_coordinate = urban_area["fare"].mean()
urban_bubbleplot_size = urban_area["driver_count"].mean()

suburban_area = pyber_df[pyber_df["type"] == "Suburban"].groupby([pyber_df["city"]])
suburban_x_coordinate = suburban_area["ride_id"].count()
suburban_y_coordinate = suburban_area["fare"].mean()
suburban_bubbleplot_size = suburban_area["driver_count"].mean()

rural_area = pyber_df[pyber_df["type"] == "Rural"].groupby([pyber_df["city"]])
rural_x_coordinate = rural_area["ride_id"].count()
rural_y_coordinate = rural_area["fare"].mean()
rural_bubbleplot_size = rural_area["driver_count"].mean()

#Information for the Scatterplot
plt.scatter(urban_x_coordinate, urban_y_coordinate, s=urban_bubbleplot_size * 5,
            label = "Urban", marker="o", facecolors="coral", edgecolors="black", alpha=0.75)
plt.scatter(suburban_x_coordinate, suburban_y_coordinate, s=suburban_bubbleplot_size * 5,
            label = "Suburban", marker="o", facecolors="lightskyblue", edgecolors="black", alpha=0.75)
plt.scatter(rural_x_coordinate, rural_y_coordinate, s=rural_bubbleplot_size * 5,
            label = "Rural", marker="o", facecolors="gold", edgecolors="black", alpha=0.75)

#Format the Scatterplot
plt.title("Pyber Ride Sharing Data (2016)")
plt.xlabel("Total Number of Rides (Per City)")
plt.ylabel("Average Fare ($)")

plt.grid()

legend = plt.legend(fontsize = 10, title= "City Types", loc= "best")

legend.legendHandles[0]._sizes = [75]
legend.legendHandles[1]._sizes = [75]
legend.legendHandles[2]._sizes = [75]

plt.text(43,36, "Note: Size of Bubble Corresponds to the Count of Drivers in a City", fontsize = 10)

#Save Scatterplot as a PNG
plt.savefig("PyberRideSharingData.png", bbox_inches="tight")

plt.show()

# %%
#Groupby with Type as the Index and Sum the Fares
type_ride_city = pyber_df.groupby(["type"])
total_fare_city = type_ride_city["fare"].sum()

#Format the Pie Chart
labels = ["Rural", "Suburban", "Urban"]
colors = ["gold", "lightskyblue", "coral"]
explode = (0, 0, 0.1)
plt.pie(total_fare_city, labels=labels, colors=colors, explode=explode, autopct="%1.1f%%", shadow=True, startangle=100)
plt.title("% of Total Fares by City Type")

#Save Pie Chart as PNG
plt.savefig("TotalFaresbyCityType")

plt.show()

# %%
#Groupby with Type as the Index and Count the Ride IDs
type_ride_city = pyber_df.groupby(["type"])
total_rides_city = type_ride_city["ride_id"].count()

#Format the Pie Chart
labels = ["Rural", "Suburban", "Urban"]
colors = ["gold", "lightskyblue", "coral"]
explode = (0, 0, 0.1)
plt.pie(total_rides_city, labels=labels, colors=colors, explode=explode, autopct="%1.1f%%", shadow=True, startangle=100)
plt.title("% of Total Rides by City Type")

#Save Pie Chart as PNG
plt.savefig("TotalRidesbyCityType")

plt.show()

# %%
#Groupby with Type as the Index and Sume the Count of Drivers
type_city = city_data.groupby(["type"])
total_drivers_city = type_city["driver_count"].sum()

#Format the Pie Chart
labels = ["Rural", "Suburban", "Urban"]
colors = ["gold", "lightskyblue", "coral"]
explode = (0, 0, 0.1)
plt.pie(total_drivers_city, labels=labels, colors=colors, explode=explode, autopct="%1.1f%%", shadow=True, startangle=100)
plt.title("% of Total Drivers by City Type")

#Save Pie Chart as PNG
plt.savefig("TotalDriversbyCityType")

plt.show()
